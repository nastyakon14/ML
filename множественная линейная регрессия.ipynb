# %% [markdown]
# #  Множественная линейная регрессия

# %% [markdown]
# 1. построить предиктивную модель предсказания целевой переменной в зависимости от значения нескольких факторов (признаков).
# 2. Загрузите датасет из приложения. Вам понадобится два файла - отдельно с признаками (помечен x) и значениями целевой переменной (помечен y). Файлы не содержат заголовков столбцов и строк. Выведите первые строки датасета.
# 3. Сделайте количественное описание датасета: количество точек данных, признаков, статистику по каждому признаку.
# 4. Для целевой и каждого из признаков постройте парную регрессионную модель. Визуализируйте линию регрессии и исходные данные на графике. При помощи коэффициентов оцените силу связи.
# 5. Постройте модель множественной линейной регрессии целевой переменной от всех показателей. Оцените качество регрессии, сделайте вывод.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = pd.read_csv("https://raw.githubusercontent.com/koroteevmv/ML_course/main/ML1.2_regression/data/0_x.csv", header = None)    # признаки
x.head()
# Out:
#           0         1         2         3         4
# 0  0.071841  0.855352 -0.305597  0.028253  1.826895
# 1  0.139521 -0.423507  0.461059 -0.447400 -0.034988
# 2  1.626311 -0.257622 -0.697520  1.413219  1.086292
# 3 -1.183233 -0.826343  0.073047 -0.639690 -0.503273
# 4 -0.783365 -0.861232  0.951448 -0.117306  0.680597

# %%
y = pd.read_csv('https://raw.githubusercontent.com/koroteevmv/ML_course/main/ML1.2_regression/data/0_y.csv', header = None)    # целевая переменная
y.head()
# Out:
#             0
# 0   63.320498
# 1  -23.426394
# 2   11.982771
# 3 -102.883304
# 4  -49.373475

# %%
x.shape, y.shape   # размерность
# Out:
# ((387, 5), (387, 1))

# %%
binary = LinearRegression()    # объект модели

# %%
binary.fit(x[[1]], y)    # построение зависмости y от одного параметра х
# Out:
# LinearRegression()

# %%
# метод подстроил коэффициенты линейной модели таким образом, чтобы функция модели была как можно ближе к точкам

# %%
binary.coef_    # коэффициенты bn
# Out:
# array([[95.52010745]])

# %%
binary.predict(x[[1]])     # теоретические значения признака
# Out:
# array([[  81.7066754 ],
#        [ -40.45008468],
#        [ -24.60472955],
#        [ -78.92903986],
#        [ -82.26167214],
#        [  90.61516808],
#        [   3.20559483],
#        [ -27.39642608],
#        [  77.03125467],
#        [ -81.79074091],
#        [ -57.11517633],
#        [  71.55969853],
#        [ -51.83704209],
#        [  13.20326205],
#        [ -20.052765  ],
#        [ 125.1294343 ],
#        [ -85.37964253],
#        [ -67.97795874],
#        [  62.50833807],
#        [  67.06343892],
#        [ -62.27425459],
#        [ -80.86610767],
#        [ -27.05138056],
#        [ -52.78366471],
#        [  35.41921651],
#        [ -79.36741675],
#        [  56.64287014],
#        [  79.27353864],
#        [ -35.49555901],
#        [-221.02386024],
#        [ -80.76607115],
#        [ 165.15522994],
#        [  32.58309404],
#        [ -35.52849481],
#        [ -96.01738449],
#        [ -42.18812152],
#        [ -48.92932082],
#        [ -75.29745421],
#        [  14.5207672 ],
#        [  38.22303712],
#        [  -5.81538928],
#        [ -10.78305653],
#        [-160.67473236],
#        [ -24.04154649],
#        [ -11.539913  ],
#        [-153.21372804],
#        [  42.71613768],
#        [ -24.64631168],
#        [ -26.34379485],
#        [ -44.84902895],
#        [  40.59122298],
#        [  67.87447367],
#        [ 149.49931095],
#        [  -9.94584466],
#        [  72.09386938],
#        [  42.61221784],
#        [ -90.05010293],
#        [-195.17725103],
#        [  31.10609487],
#        [-179.11440495],
#        [ -68.01785401],
#        [  66.14535672],
#        [  46.04652432],
#        [-115.88877487],
#        [ -51.23726237],
#        [ -23.25825104],
#        [ 183.28767615],
#        [  42.06612485],
#        [ -61.68157548],
#        [  18.85284738],
#        [   8.29279789],
#        [  24.15702881],
#        [-132.25876571],
#        [-221.602558  ],
#        [  63.95970687],
#        [  70.05523606],
#        [ 101.35968876],
#        [  42.00528659],
#        [ -26.1669863 ],
#        [-142.57321028],
#        [  26.4302692 ],
#        [ -68.27127373],
#        [  77.68098549],
#        [   4.65591819],
#        [-275.75541696],
#        [ -18.03885794],
#        [ -65.15813567],
#        [  19.70062088],
#        [   2.30319232],
#        [-128.62567157],
#        [ -21.38042389],
#        [ 265.49792197],
#        [-232.79954877],
#        [  49.37518101],
#        [  46.59420205],
#        [ -66.70043384],
#        [ 135.3863095 ],
#        [ -20.73454969],
#        [ 153.12546539],
#        [  12.18146666],
#        [ -28.6152795 ],
#        [ 220.9291044 ],
#        [ -67.38550484],
#        [  54.67498213],
#        [ 146.49036594],
#        [-178.02357604],
#        [ 122.1816615 ],
#        [ -61.14413136],
#        [ -27.09696207],
#        [-162.71427576],
#        [ 250.11274891],
#        [-107.95714296],
#        [ -31.99055553],
#        [-125.12658808],
#        [ -43.28882518],
#        [ -48.08193349],
#        [ -14.84293043],
#        [ -49.99447436],
#        [  85.64858815],
#        [  48.0955124 ],
#        [ -12.70621587],
#        [ 106.29897038],
#        [ -18.39771021],
#        [ 131.8451858 ],
#        [ -49.15634037],
#        [   1.68833334],
#        [ 118.20821483],
#        [  93.32592767],
#        [  97.43196106],
#        [  41.90411351],
#        [-280.60718038],
#        [-197.29803704],
#        [ -81.67903369],
#        [ -31.55191845],
#        [  -8.98441752],
#        [  17.69645515],
#        [ -93.38459812],
#        [  39.46140888],
#        [ -10.04059876],
#        [ -45.14876349],
#        [ -75.91237642],
#        [-112.22661212],
#        [ 170.79517534],
#        [ 115.74079081],
#        [-162.39097497],
#        [ 105.17957504],
#        [ 154.74063944],
#        [  92.53223282],
#        [   6.9455845 ],
#        [-225.11827841],
#        [  63.11488128],
#        [  25.88212457],
#        [  39.19303711],
#        [ 141.26212896],
#        [ 122.432238  ],
#        [-263.473649  ],
#        [  -3.03374485],
#        [  97.40443477],
#        [  27.13542993],
#        [   5.3268769 ],
#        [ 109.40126709],
#        [ 187.77919778],
#        [  58.54396916],
#        [ 173.08930384],
#        [  -7.38389923],
#        [  -0.61716853],
#        [  15.9525564 ],
#        [ -56.74240282],
#        [  -9.43822359],
#        [ -12.58372954],
#        [  42.85873442],
#        [ -68.6263664 ],
#        [ -26.44110218],
#        [ -10.14910195],
#        [ -65.0326574 ],
#        [ 118.01212374],
#        [ 185.63095006],
#        [  80.68142722],
#        [ -22.36445142],
#        [  24.20376479],
#        [  91.92751024],
#        [ 123.84015615],
#        [  10.63661408],
#        [  38.14606475],
#        [  91.04662802],
#        [  -0.36732981],
#        [ 172.93200509],
#        [  15.84684686],
#        [  49.28739805],
#        [ -33.79697395],
#        [  54.96341913],
#        [ -10.50881915],
#        [-192.69059444],
#        [ -76.97685798],
#        [ 134.327864  ],
#        [ 111.50420719],
#        [ 126.56309706],
#        [-134.69906739],
#        [  75.62820656],
#        [  -1.70241194],
#        [  77.7070228 ],
#        [ -17.20936769],
#        [ 219.16998941],
#        [-136.13812314],
#        [ -66.21493546],
#        [ -55.27141374],
#        [ -70.4956149 ],
#        [ -43.24693497],
#        [  -7.07072434],
#        [ -20.91968838],
#        [ -40.80563876],
#        [ 141.13861597],
#        [  43.73042813],
#        [-195.48276684],
#        [   9.16176867],
#        [-105.62627143],
#        [ -10.67867476],
#        [   2.38472055],
#        [ 193.68921008],
#        [-115.63833686],
#        [  43.03267889],
#        [-147.37305219],
#        [  86.11484884],
#        [ -83.55847418],
#        [  30.71755434],
#        [  10.27639553],
#        [ -41.32557351],
#        [-140.26912202],
#        [ 128.01969105],
#        [ 183.95884118],
#        [   6.86531718],
#        [ -62.61269229],
#        [  66.06452798],
#        [ -47.63542055],
#        [ -85.17778107],
#        [ -15.72430026],
#        [  40.54649993],
#        [ -33.61879412],
#        [  31.76513237],
#        [-169.66712596],
#        [-110.88659879],
#        [ -77.04563955],
#        [  70.71761787],
#        [ -85.21453659],
#        [  41.92732181],
#        [ -13.68225282],
#        [ -67.49116957],
#        [  11.93379948],
#        [  50.18679576],
#        [ -21.66912636],
#        [  32.60453994],
#        [  14.09090855],
#        [ -27.33493738],
#        [-136.21711333],
#        [ -15.0605813 ],
#        [  49.78409122],
#        [-146.33455004],
#        [  71.63976509],
#        [  34.84132967],
#        [  12.30331257],
#        [  25.11261985],
#        [ -82.94602459],
#        [  83.54118867],
#        [ -57.88777693],
#        [  33.51754325],
#        [ -13.26429964],
#        [  65.85659717],
#        [  15.31444989],
#        [  67.81035688],
#        [  37.90075022],
#        [-167.10852275],
#        [ -57.99444761],
#        [ -36.00913797],
#        [  19.70290791],
#        [  33.45100315],
#        [-193.37192207],
#        [-121.15413667],
#        [  44.49224941],
#        [ -56.1373161 ],
#        [-153.69832577],
#        [ -80.50677918],
#        [-139.94014044],
#        [-192.67844919],
#        [ -54.64561087],
#        [  25.28740192],
#        [  25.07178482],
#        [   6.18083304],
#        [ 119.12500939],
#        [  46.71009304],
#        [  59.95782773],
#        [  83.74304754],
#        [ -99.02017347],
#        [ -87.68936548],
#        [  35.26396331],
#        [ 113.46685456],
#        [  42.5318588 ],
#        [  76.49714278],
#        [  99.83898538],
#        [ 112.30715761],
#        [ -12.15256336],
#        [ -29.02289519],
#        [  -6.97000698],
#        [ -37.7981597 ],
#        [ -52.4957794 ],
#        [ -98.02566506],
#        [ -18.49808937],
#        [ 134.54606734],
#        [ -21.78679736],
#        [  54.63789894],
#        [  59.63899484],
#        [ 157.32491005],
#        [  24.15363445],
#        [-121.14867961],
#        [ -32.74519018],
#        [-131.35579455],
#        [-100.53610905],
#        [  33.51745925],
#        [-221.78986989],
#        [  54.30924205],
#        [ -49.99624045],
#        [ -19.03749344],
#        [  -3.89300243],
#        [  -2.00342034],
#        [  69.27371782],
#        [ 234.02597915],
#        [  17.39055722],
#        [  14.93614571],
#        [ 148.66540159],
#        [  32.60167026],
#        [ 123.16186748],
#        [  61.24969494],
#        [  19.53920496],
#        [  25.02661721],
#        [ -75.38829513],
#        [ 166.41096829],
#        [ -47.99621481],
#        [ -25.77216712],
#        [ -48.96112576],
#        [ 105.43118884],
#        [   0.52022763],
#        [-336.85664107],
#        [  55.4750755 ],
#        [  72.33167816],
#        [-125.0236379 ],
#        [  20.70080008],
#        [ -57.91225848],
#        [  15.14114254],
#        [ -73.0099126 ],
#        [ 104.69214051],
#        [  50.24679881],
#        [  88.86557698],
#        [  68.28375578],
#        [ 122.95171668],
#        [ -25.0625463 ],
#        [  14.95429697],
#        [ -25.53926062],
#        [ 119.59087486],
#        [ 118.23947123],
#        [  43.99690047],
#        [ -21.1075395 ],
#        [ -17.25817459],
#        [  -2.62354642],
#        [  26.91692081],
#        [  10.15184644],
#        [  -9.48628965],
#        [ -81.84415436],
#        [ -68.05161774],
#        [-197.88761328],
#        [ -22.00916557],
#        [ 109.53859278],
#        [ -53.08749143],
#        [-153.71615885],
#        [  44.87328563],
#        [-157.42934885],
#        [-127.98274416],
#        [-166.53394014],
#        [ -61.33081485],
#        [ -11.77940539],
#        [  15.34513479],
#        [   3.0680711 ],
#        [-176.57818911],
#        [  13.43212536],
#        [ 221.67948236],
#        [ 200.32727577],
#        [  89.86779245],
#        [-115.55742864],
#        [  68.35801214]])

# %%
plt.scatter(x[[1]], y)     # график зависимости

# %%
plt.scatter(x[[1]], y)     # график зависимости
xx = np.linspace(x[1].min(), x[1].max(), 100).reshape((-1, 1))    # арифметическая прогрессия
plt.plot(xx, binary.predict(xx), c='r')

# %%
# сделаем то же самое для множественной регрессии

# %%
multiple = LinearRegression()
multiple.fit(x, y)
multiple.score(x, y)    # почти идеальная модель
# Out:
# 0.9922198026415868

# %%
yy = multiple.predict(x)
plt.scatter(yy, y)
plt.plot(y, y, c='r')    # y = y

# %% [markdown]
# # задания для самостоятельного выполнения

# %% [markdown]
# 1. Сравните коэффициенты парной и множественной регрессии до и после обучения.

# %%
binary.intercept_, binary.coef_    # коэффициенты и0 и b1 для парной регерссии
# Out:
# (array([0.00332092]), array([[95.52010745]]))

# %%
multiple.intercept_, multiple.coef_    # коэффициенты множественной регрессии
# Out:
# (array([0.56498354]),
#  array([[15.79537523, 93.21521093, 37.19410687, 31.19129121, -0.23773114]]))

# %% [markdown]
# 2. Самостоятельно постройте парные регрессии от каждого атрибута с целевой переменной.

# %%
model0 = LinearRegression()
model0.fit(x[[0]], y)   # обучение модели
model0.predict(x[[0]])    # предсказания модели
plt.scatter(x[[0]], y)
x0 = np.linspace(x[0].min(), x[0].max(), len(x[0])).reshape((-1, 1))
plt.plot(x0, binary.predict(x0), c='r')

# %%
model1 = LinearRegression()
model1.fit(x[[1]], y)   # обучение модели
model1.predict(x[[1]])    # предсказания модели
plt.scatter(x[[1]], y)
x1 = np.linspace(x[1].min(), x[1].max(), len(x[1])).reshape((-1, 1))
plt.plot(x1, binary.predict(x1), c='r')

# %%
model2 = LinearRegression()
model2.fit(x[[2]], y)   # обучение модели
model2.predict(x[[2]])    # предсказания модели
plt.scatter(x[[2]], y)
x2 = np.linspace(x[2].min(), x[2].max(), len(x[2])).reshape((-1, 1))
plt.plot(x2, binary.predict(x2), c='r')

# %%
model3 = LinearRegression()
model3.fit(x[[3]], y)   # обучение модели
model3.predict(x[[3]])    # предсказания модели
plt.scatter(x[[3]], y)
x3 = np.linspace(x[3].min(), x[3].max(), len(x[3])).reshape((-1, 1))
plt.plot(x3, binary.predict(x3), c='r')

# %%
model4 = LinearRegression()
model4.fit(x[[4]], y)   # обучение модели
model4.predict(x[[4]])    # предсказания модели
plt.scatter(x[[4]], y)
x4 = np.linspace(x[4].min(), x[4].max(), len(x[4])).reshape((-1, 1))
plt.plot(x4, binary.predict(x4), c='r')

# %% [markdown]
# 3. Для целевой переменной и каждого из признаков постройте полиномиальную регрессию второго, третьего и десятого порядков. Сделайте вывод о значимости регрессии.

# %% [markdown]
# - 2 порядок

# %% [markdown]
# $y = b_0 + b_1x + b_2x^2$

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly2 = PolynomialFeatures(degree = 2, include_bias= False)    # intercept_ != 0, degree -- степень полинома
poly2
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_feauters2 = poly2.fit_transform(x)    # обчение модели
poly_feauters2
# Out:
# array([[ 7.18411922e-02,  8.55352414e-01, -3.05596614e-01, ...,
#          7.98207711e-04,  5.16144893e-02,  3.33754670e+00],
#        [ 1.39521454e-01, -4.23506701e-01,  4.61059013e-01, ...,
#          2.00166735e-01,  1.56534519e-02,  1.22413226e-03],
#        [ 1.62631129e+00, -2.57621679e-01, -6.97519642e-01, ...,
#          1.99718849e+00,  1.53516867e+00,  1.18003026e+00],
#        ...,
#        [-4.57140543e-01,  9.40791148e-01, -6.60269560e-01, ...,
#          5.40868523e+00, -3.51187134e+00,  2.28026587e+00],
#        [-3.44277715e-01, -1.20980548e+00, -2.11972090e+00, ...,
#          2.20792023e+00,  2.49169934e-01,  2.81195194e-02],
#        [-1.34911367e+00,  7.15605259e-01,  1.27304466e+00, ...,
#          6.12758536e-01, -5.35207989e-01,  4.67472217e-01]])

# %%
poly_feauters2.shape
# Out:
# (387, 20)

# %% [markdown]
# - 3 степень

# %% [markdown]
# $y = b_0 + b_1x + b_2x^2 + b_3x^3$

# %%
poly3 = PolynomialFeatures(degree = 3, include_bias= False)    # intercept_ != 0, degree -- степень полинома
poly_features3 = poly3.fit_transform(x)   
poly_features3
# Out:
# array([[ 7.18411922e-02,  8.55352414e-01, -3.05596614e-01, ...,
#          1.45824197e-03,  9.42942717e-02,  6.09734861e+00],
#        [ 1.39521454e-01, -4.23506701e-01,  4.61059013e-01, ...,
#         -7.00335394e-03, -5.47676737e-04, -4.28294516e-05],
#        [ 1.62631129e+00, -2.57621679e-01, -6.97519642e-01, ...,
#          2.16952983e+00,  1.66764141e+00,  1.28185740e+00],
#        ...,
#        [-4.57140543e-01,  9.40791148e-01, -6.60269560e-01, ...,
#         -8.16741175e+00,  5.30311861e+00, -3.44332670e+00],
#        [-3.44277715e-01, -1.20980548e+00, -2.11972090e+00, ...,
#         -3.70243401e-01, -4.17829966e-02, -4.71532728e-03],
#        [-1.34911367e+00,  7.15605259e-01,  1.27304466e+00, ...,
#          4.18954898e-01, -3.65932085e-01,  3.19619823e-01]])

# %%
poly_features3.shape
# Out:
# (387, 55)

# %% [markdown]
# - 10 степень

# %% [markdown]
# $y = b_0 +b_1x + ... +b_{10}x^{10}$

# %%
poly10 = PolynomialFeatures(degree = 10, include_bias= False)    # intercept_ != 0, degree -- степень полинома
poly_features10 = poly10.fit_transform(x)   
poly_features10
# Out:
# array([[ 7.18411922e-02,  8.55352414e-01, -3.05596614e-01, ...,
#          9.90433502e-02,  6.40443818e+00,  4.14130059e+02],
#        [ 1.39521454e-01, -4.23506701e-01,  4.61059013e-01, ...,
#          4.49474724e-13,  3.51498514e-14,  2.74879095e-15],
#        [ 1.62631129e+00, -2.57621679e-01, -6.97519642e-01, ...,
#          3.87250177e+00,  2.97665614e+00,  2.28805106e+00],
#        ...,
#        [-4.57140543e-01,  9.40791148e-01, -6.60269560e-01, ...,
#          1.46229049e+02, -9.49468463e+01,  6.16491984e+01],
#        [-3.44277715e-01, -1.20980548e+00, -2.11972090e+00, ...,
#          1.38043180e-06,  1.55785565e-07,  1.75808339e-08],
#        [-1.34911367e+00,  7.15605259e-01,  1.27304466e+00, ...,
#          2.92625783e-02, -2.55591147e-02,  2.23243603e-02]])

# %%
poly_features10.shape
# Out:
# (387, 3002)

# %% [markdown]
# 4. Постройте сводную таблицу показателей точности всех построенных моделей. Сделайте вывод, какие модели переобученнные, какие - недообученные.

# %%
pd.DataFrame()

# %% [markdown]
# 5. Используйте другие метрики качества регрессионной модели в дополнение к коэффициенту детерминации.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)   # разбивает на тестовые и обучающие данные
slr = LinearRegression()

slr.fit(X_train, y_train)
y_train_pred = slr.predict(X_train)   # предсказание обученных данных
y_test_pred = slr.predict(X_test)    # предсказание тестовых данных

# %%
plt.scatter(y_train_pred,  y_train_pred - y_train,
            c='blue', marker='o', label='Training data')
plt.scatter(y_test_pred,  y_test_pred - y_test,
            c='lightgreen', marker='s', label='Test data')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, r2_score

print('MSE train: {:.3f}, test: {:.3f}'.format(           # среднеквадратичная ошибка
        mean_squared_error(y_train, y_train_pred),
        mean_squared_error(y_test, y_test_pred)))
print('R^2 train: {:.3f}, test: {:.3f}'.format(
        r2_score(y_train, y_train_pred),
        r2_score(y_test, y_test_pred)))    # коэф детерминации
# Out:
# MSE train: 91.352, test: 100.630
# R^2 train: 0.992, test: 0.993

# %% [markdown]
# 6. (*) Замерьте время обучения полиномиальных моделей с разной степенью полинома. Сделайте вывод.

# %%
import time

for i in range(1,11):
  x = pd.read_csv("https://raw.githubusercontent.com/koroteevmv/ML_course/main/ML1.2_regression/data/0_x.csv", header = None) 
  poly = PolynomialFeatures(degree = i, include_bias= False)    # intercept_ != 0, degree -- степень полинома
  start = time.time()    # время на данный момент
  poly_features = poly.fit_transform(x)   
  end = time.time()
  print(f'time with degree {i}: {end - start}')
# Out:
# time with degree 1: 0.0027229785919189453
# time with degree 2: 0.0026988983154296875
# time with degree 3: 0.0035109519958496094
# time with degree 4: 0.0029304027557373047
# time with degree 5: 0.003448486328125
# time with degree 6: 0.004300117492675781
# time with degree 7: 0.006246805191040039
# time with degree 8: 0.007438182830810547
# time with degree 9: 0.007831096649169922
# time with degree 10: 0.011855363845825195

# %%
# с увеличением степени полинома время обучения модели увеличивается

# %% [markdown]
# # Контрольные вопросы

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Применение любых моделей машинного обучения начинается с подготовки данных в необходимом формате. Для этого очень удобными для нас будут библиотеки numpy и pandas. Они практически всегда используются совместно с библиотекой sckikit-learn и другими инструментами машинного обучения. В первую очередь мы будем использовать numpy для создания массивов и операций с векторами и матрицами. Pandas нам понадобится для работы с табличными структурами - датасетами.
#
# Если вы хотите самостоятельно задать в явном виде данные обучающей выборки, то нет ничего лучше использования обычных массивов ndarray. Обычно в одном массиве хранятся значения атрибутов - x, а в другом - значения целевой переменной - y.

# %% [markdown]
# 2. Смысл коэффициента регрессии
#
# • В общем случае коэффициент регрессии k показывает, как в среднем изменится результативный признак ( Y ), если факторный признак ( X ) увеличится на единицу

# %% [markdown]
# 3. Парная регрессия - это когда у нас всего один атрибут. Множественная - когда больше одного.  Множественная регрессия очень похожа на парную, но с большим количеством признаков.

# %% [markdown]
# 4. В задачах регрессии в качестве функции ошибки чаще всего берут среднеквадратичное отклонение теоретических значений от эмпирических. То есть сумму квадратов отклонений, деленную на удвоенное количество измерений.

# %% [markdown]
# 5. Среднеквадратичная ошибка (MSEMSE).\
# Корень из среднеквадратичной ошибки (RMSERMSE).\
# Среднеквадратичная ошибка в процентах (MSPEMSPE).\
# Средняя абсолютная ошибка (MAEMAE).\
# Средняя абсолютная ошибка в процентах (MAPEMAPE).\
# Cимметричная средняя абсолютная процентная ошибка (SMAPESMAPE).\
# Средняя абсолютная масштабированная ошибка (MASEMASE)\
# Средняя относительная ошибка (MREMRE).\
# Среднеквадратичная логарифмическая ошибка (RMSLERMSLE).\
# Коэффициент детерминации RR-квадрат.\
# Скорректированный коэффициент детеминации.

# %% [markdown]
# 6. 10 популярных методов регрессии
#
# Линейная регрессия
# from sklearn.linear_model import LinearRegression
# Регрессор ЛГБМ
#
# from lightgbm import LGBMRegressor
# Регрессор XGBoost
#
# from xgboost.sklearn import XGBRegressor
# CatBoost Regressor
#
# from catboost import CatBoostRegressor
# Стохастическая регрессия градиентного спуска
#
# from sklearn.linear_model import SGDRegressor
# Регрессия кернел-риджа
#
# from sklearn.kernel_ridge import KernelRidge
# Эластичная чистая регрессия
#
# from sklearn.linear_model import ElasticNet
# Bayesian Ridge Regression
#
# from sklearn.linear_model import BayesianRidge
# Регрессия с усилением градиента
#
# from sklearn.ensemble import GradientBoostingRegressor
# Машина опорных векторов
#
# from sklearn.svm import SVR
